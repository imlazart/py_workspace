# %%
class sample:

    def __init__(self):
        print("init method");
        self.lv_total = 100;

    def add(self):
        print("function-1");
        print(self.lv_total);
        self.b= self.lv_total + 50;


    def sub(self):
        print("function-2");
        print(self.b);

# %%
a = sample();
# Out:
# init method

# %%
a.add();
# Out:
# function-1
# 100

# %%
a.sub();
# Out:
# function-2
# 150

# %%
# Out:
# 10
# 20

# %%
print("test")
# Out:
# test
