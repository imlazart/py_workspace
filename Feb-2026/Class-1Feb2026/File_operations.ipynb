# %%
with open(r"C:\Users\LazarThomas\Desktop\sample.txt", "r") as f:
    a = f.read();
    print(a);
# Out:
# This is a test file

# %%
with open(r"C:\Users\LazarThomas\Desktop\sample.txt", "w") as f:
    a = f.tell();
    print(a);
    f.write("Replaced text");
    print(f.tell);
# Out:
# 0
# <built-in method tell of _io.TextIOWrapper object at 0x0000026699DFA180>

# %%
with open(r"C:\Users\LazarThomas\Desktop\sample.txt", "a") as f:
    a = f.tell();
    print(a);
    f.write("lazar");
    print(f.tell);
# Out:
# 13
# <built-in method tell of _io.TextIOWrapper object at 0x0000026699DF9620>

# %%
with open(r"C:\Users\LazarThomas\Desktop\sample.txt", "r+  ") as f:
    a = f.tell();
    print(a);
    f.write("lazar");
    print(f.tell);
