# %%
family_members = {"lazar", "sarah", "kalps","sarah"}

# %%
family_members
# Out:
# {'kalps', 'lazar', 'sarah'}

# %%
a= {"lazar", "sarah", "kalps","sarah"}

# %%
sorted(a, reverse = True)
# Out:
# ['sarah', 'lazar', 'kalps']
