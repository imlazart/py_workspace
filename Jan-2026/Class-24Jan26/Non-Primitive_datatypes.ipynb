# %%
a = ["azaz", "dracula", "vlad"]

# %%
a.append("lazar")

# %%
a.append("[1,2,1,]")

# %%
a.append("[1515,2,1], 545",)

# %%
a
# Out:
# ['azaz', 'dracula', 'vlad', 'lazar', '[1,2,1,]', '[1515,2,1], 545']

# %%
a.append("[1515,2,1], 545, 'lazar'",)

# %%
a
# Out:
# ['azaz',
#  'dracula',
#  'vlad',
#  'lazar',
#  '[1,2,1,]',
#  '[1515,2,1], 545',
#  "[1515,2,1], 545, 'lazar'"]

# %%
len(a)
# Out:
# 7

# %%
a.count("lazaaaaaar")
# Out:
# 0

# %%
a.pop()
# Out:
# "[1515,2,1], 545, 'lazar'"

# %%
a
# Out:
# ['azaz', 'dracula', 'vlad', 'lazar', '[1,2,1,]', '[1515,2,1], 545']

# %%
a.pop()
# Out:
# '[1515,2,1], 545'

# %%
a
# Out:
# ['azaz', 'dracula', 'vlad', 'lazar', '[1,2,1,]']
