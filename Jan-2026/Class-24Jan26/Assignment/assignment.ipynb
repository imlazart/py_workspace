# %% [markdown]
# # Python Logic & Loops: Real-World Assignment (21-01-2026-UDS-2.0)

# %% [markdown]
# ### 1. The Office Door Badge
#
# You are programming a smart door for a tech office.
# The door should only open if the user provides the correct "Access Code."
# Input: User enters a 4-digit code.
# Scenario: If the code is
# 1234 , print "Access Granted. Door Unlocked." Otherwise, print "Access Denied.
# Security Alerted."

# %%
a_code = input("Enter the Access Code: ")

if a_code == "1234":
    print("Access Granted. Door Unlocked.")
else:
    print("Access Denied. Please enter the correct code.")
# Out:
# Access Granted. Door Unlocked.

# %% [markdown]
# ### 2. The Weekend Grocery Trip
# A person is deciding whether to go to the supermarket.
# Input: User enters how many eggs are left in the fridge (integer).
# Scenario: If the number of eggs is less than 3, print "Time to go to the market!" Else, print "You have
# enough for breakfast today."

# %%
a_eggs = input("Enter number of eggs: ")

if a_eggs.isdigit():
    a_eggs = int(a_eggs)
    if a_eggs < 3:
        print("Time to go to the market!")
    else:
        print("You have enough eggs for breakfast today.")
else:
    print("error: please enter a valid number")
# Out:
# You have enough eggs for breakfast today.

# %% [markdown]
# ### 3. The Smart Home "Leaving for Work" Checklist
#  When you leave your house, a smart assistant checks multiple
# independent things. These are not mutually exclusive.
# Input: Three separate inputs (Yes/No) for: "Is the AC on?", "Is the Coffee Maker on?", "Is the Front Door
# unlocked?"
# Scenario:
# If AC is on Print "Turning off AC to save energy."
# If Coffee Maker is on Print "Warning: Coffee Maker is still hot!"
# If Door is unlocked Print "Locking the front door now." (Note: All three messages could potentially print.

# %%
ac_check      = input("Is the AC on?(Yes/No): ");
coffee_check  = input("Is there coffee maker On?(Yes/No): ");
f_door_check  = input("Is the front door locked?(Yes/No): ");

if ac_check == 'Yes' and coffee_check == 'Yes' and f_door_check == 'Yes':
    print("All is well")
elif ac_check == 'No' and coffee_check == 'No' and f_door_check == 'No':
    print("Reminder!!! Turn off AC to save energy.")
    print("Warning: Coffee Maker is still hot!")
    print("Locking the front door now.")
elif ac_check == 'No':
    print("Reminder!!! Turn off AC to save energy.")
elif coffee_check == 'No':
    print("Warning: Coffee Maker is still hot!")
elif f_door_check == 'No':
    print("Locking the front door now.")
# Out:
# Reminder!!! Turn off AC to save energy.
# ...
# Locking the front door now.

# %% [markdown]
# ### 4. The Pizza Topping Calculator
# A customer is choosing toppings. Each topping adds a specific cost regardless of
# the other toppings chosen.
# Input: Three boolean (True/False) inputs for:
# Scenario: Initialize a
# If
# total_bill = 10 .
# extra_cheese is True add 2 to bill.
# If
# pepperoni is True add 3 to bill.
# If
# olives is True add 1 to bill.
# Output: Print the final total bill

# %%
total_bill = 0
extra_cheese      = input("Need Extra Cheese?(True/False): ");
pepperoni  = input("Need Extra Pepperoni?(True/False): ");
olives  = input("Need Extra Olives?(True/False): ");


total_bill = 10;
for i in range(0,3):
    if extra_cheese == "True":
        total_bill += 2
    elif pepperoni == "True":
        total_bill += 3
    elif olives == "True":
        total_bill += 1



'''
if extra_cheese == "True" and pepperoni == "True" and olives == "True":
    total_bill += 2
    total_bill += 3
    total_bill += 1
elif extra_cheese == "True" && pepperoni == "True" && olives =="False":
    total_bill += 2
    total_bill += 3
elif extra_cheese == "False" && pepperoni == "True" && olives =="True":
    total_bill += 3
    total_bill += 1
elif extra_cheese == "True" && pepperoni == "False" && olives =="True":
    total_bill += 2
    total_bill += 1
elif extra_cheese == "True" && pepperoni == "True" && olives =="False":
    total_bill += 2
    total_bill += 1
    '''

print(total_bill)
# Out:
# 16

# %% [markdown]
# ### 5. The Traffic Light Sensor
# A self-driving car needs to interpret a single traffic light color.
# Input: User enters "Red", "Yellow", or "Green".
# Scenario: * If "Red" "Full Stop."
# If "Yellow" "Slow down and prepare to stop."
# If "Green" "Proceed with caution."
# Anything else "Error: Signal Malfunction!

# %%
traffic_light = input("Enter the Traffic Color ?:");

if traffic_light == 'Red':
    print("Full Stop.");
elif traffic_light == 'Yellow':
    print("Slow down and prepare to stop.");
elif traffic_light == 'Green':
    print("Proceed with caution.");
else:
    print( "Error: Signal Malfunction!");
# Out:
# Error: Signal Malfunction!

# %% [markdown]
# ### 6. Movie Theater Ticket Pricing
# A theater charges based on the age of the customer.
# Input: User enters their age.
# Scenario:
# Age < 5 "Ticket is Free."
# Age 5 to 17 "Child Ticket: $10."
# Age 18 to 60 "Adult Ticket: $18."
# Age > 60 "Senior Ticket: $12.

# %%
age = int(input("Enter the age ?:"));

if age < 5:
    print("Free Ticket :) ");
elif age  >=5 and age < 17:
    print("Child Ticket: $10.");
elif (age  >=18) and (age < 60):
    print("Adult Ticket: $18.");
else:
    print( "Senior Ticket: $12.");
# Out:
# Child Ticket: $10.

# %% [markdown]
# ### 7. The 7-Day Steps Tracker
# A fitness app wants to show your activity for the week.
# Data: A list of steps:
# [4000, 7500, 10000, 2000, 8000, 12000, 5000] .
# Scenario: Loop through the list and for each day, print: "Day [X]: You walked [Steps] steps.

# %%
steps = [4000, 7500, 10000, 2000, 8000, 12000, 5000]
days =0
for i in steps:
    days += 1
    print("Day " ,  days , " : You have walked " , i)
# Out:
# Day  1  : You have walked  4000
# Day  2  : You have walked  7500
# Day  3  : You have walked  10000
# Day  4  : You have walked  2000
# Day  5  : You have walked  8000
# Day  6  : You have walked  12000
# Day  7  : You have walked  5000

# %% [markdown]
# ### The Email "Bcc" System
# A marketing manager has a list of 5 client names.
# Input: A list containing 5 names.
# Scenario: Use a loop to "send" an email to each person by printing: "Sending personalized promo code to
# [Name]...

# %%
client_names = ["Lazar", "Sarah" , "kalpana", "Thomas","Elsamma"]

for i in client_names:
    print("Sending personalized promo code to ", i)
# Out:
# Sending personalized promo code to  Lazar
# Sending personalized promo code to  Sarah
# Sending personalized promo code to  kalpana
# Sending personalized promo code to  Thomas
# Sending personalized promo code to  Elsamma

# %%
if __name__ == '__main__':
    print("hai")
# Out:
# hai
