# %%
dict = {"lazar":[38, "salem", "+91 97902 11437"], "kalps":[37, "salem", "+91 97902 11437"]}

# %%
dict
# Out:
# {'lazar': [38, 'salem', '+91 97902 11437'],
#  'kalps': [37, 'salem', '+91 97902 11437']}

# %%
dict.get("lazar")
# Out:
# [38, 'salem', '+91 97902 11437']

# %%
dict["lazar"]
# Out:
# [38, 'salem', '+91 97902 11437']

# %%
type(dict.keys())
# Out:
# dict_keys

# %%
dict.values()
# Out:
# dict_values([[38, 'salem', '+91 97902 11437'], [37, 'salem', '+91 97902 11437']])

# %%
for i in dict.values():
    print(i)
    for j in i:
        print(j)
# Out:
# [38, 'salem', '+91 97902 11437']
# 38
# salem
# +91 97902 11437
# [37, 'salem', '+91 97902 11437']
# 37
# salem
# +91 97902 11437

# %%
list(dict.values())
# Out:
# [[38, 'salem', '+91 97902 11437'], [37, 'salem', '+91 97902 11437']]

# %%
for i in list(dict.values()):
    print(i)
# Out:
# [38, 'salem', '+91 97902 11437']
# [37, 'salem', '+91 97902 11437']

# %%
dict["sarah"] = [29, "chennai", "+91 98765 43210"]

# %%
dict
# Out:
# {'lazar': [38, 'salem', '+91 97902 11437'],
#  'kalps': [37, 'salem', '+91 97902 11437'],
#  'sarah': [29, 'chennai', '+91 98765 43210']}

# %%
dict.pop("kalps")
# Out:
# [37, 'salem', '+91 97902 11437']

# %%
dict
# Out:
# {'lazar': [38, 'salem', '+91 97902 11437'],
#  'sarah': [29, 'chennai', '+91 98765 43210']}

# %%
dict.pop("lazar")
# Out:
# [38, 'salem', '+91 97902 11437']

# %%
dict
# Out:
# {'sarah': [29, 'chennai', '+91 98765 43210']}
