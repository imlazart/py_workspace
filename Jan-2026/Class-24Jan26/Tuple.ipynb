# %%
a_tuple = (101, "Alice", 23)

# %%
a_tuple.append(45)  # This will raise an AttributeError because tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a_tuple.append(45)  # This will raise an AttributeError because tuples are immutable
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
a_tuple.pop(45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a_tuple.pop(45)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
a_tuple = (22, "Alice", 23)

# %%
a_tuple
# Out:
# (22, 'Alice', 23)
