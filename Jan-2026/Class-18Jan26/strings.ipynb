# %%
a="lazar"

# %%
id(a)
# Out:
# 2538810651680

# %%
b="   lazar sarah kalpana thaomas   "

# %%
print(b);
print(b.strip());
print(b.lstrip());
print(b.rstrip());
# Out:
#    lazar sarah kalpana thaomas
# lazar sarah kalpana thaomas
# lazar sarah kalpana thaomas
#    lazar sarah kalpana thaomas

# %%
print(b.strip().rstrip());
# Out:
# lazar sarah kalpana thaomas
