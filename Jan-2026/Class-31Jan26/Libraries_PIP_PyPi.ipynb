# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Py_workspace\\level-1\\practical_codes\\Class-31Jan26'

# %%
os.listdir('c:\\Py_workspace\\level-1\\practical_codes\\Class-31Jan26')
# Out:
# ['args_kwargs.ipynb',
#  'Libraries_PIP_PyPi.ipynb',
#  'README.md',
#  'scopeofVariable.ipynb']
