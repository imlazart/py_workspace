# %%
import os

# %%
os.listdir()
# Out:
# ['args_kwargs.ipynb',
#  'fileOperations.ipynb',
#  'Libraries_PIP_PyPi.ipynb',
#  'README.md',
#  'scopeofVariable.ipynb',
#  'test.txt']

# %%
file = open("test.txt", "r")

# %%
res = file.read()
final = res.split('\n')
print(final )
# Out:
# ['hai', 'hello ', 'how are u ', '', '']

# %% [markdown]
# # if u run f.read() - it will scan each line by line and pointer goes to the end of the characters.

# %%
file = open("test.txt", "r")
res = file.readline()
#final = res.split('\n')
print(res)
file.close()
# Out:
# hai

# %%
file = open("test.txt", "r")
res = file.readlines()
print(res)      
file.close()
# Out:
# ['hai\n', 'hello \n', 'how are u \n', '\n']

# %%
file = open("test.txt")
res = file.readline()
print(res)      
file.close()
# Out:
# hai

# %%
file = open("test.txt", "r")

for i in file:
    print(i.strip())

file.close()
# Out:
# hai
# hello
# how are u

# %%
file = open("test.txt", "r")
while True:
    line = file.readline()
    if not line:
        break
    print(line.strip())
# Out:
# hai
# hello
# how are u

# %%
with open("test.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# hai
# hello
# how are u
