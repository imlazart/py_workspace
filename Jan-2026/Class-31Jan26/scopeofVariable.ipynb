# %%
a = 10;

def add():
    a = 20;
    a+=5;
    print("Inside add():", a);

print(a);
add();
print(a);
# Out:
# 10
# Inside add(): 25
# 10

# %%
a = [1, 2, 3];

res = []

res.append(a)

# %%
res
# Out:
# [[1, 2, 3], [1, 2, 3]]

# %%
res.append(a)
