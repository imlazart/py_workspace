# %%
a = 10
b = 0

while a > b:
    print(" b value is:", b);
    b+=1
# Out:
#  b value is: 0
#  b value is: 1
#  b value is: 2
#  b value is: 3
#  b value is: 4
#  b value is: 5
#  b value is: 6
#  b value is: 7
#  b value is: 8
#  b value is: 9
