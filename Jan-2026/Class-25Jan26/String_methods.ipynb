# %%
a ="lazar"

# %%
a.lower()
# Out:
# 'lazar'

# %%
a.upper()
# Out:
# 'LAZAR'

# %%
a.capitalize()
# Out:
# 'Lazar'

# %%
res = "lazar, sarah, kalpana, thomas";

# %%
res.split(", ")
#split will split a string into list based on the separator provided
# Out:
# ['lazar', 'sarah', 'kalpana', 'thomas']

# %%
res.find("w")
# Out:
# -1

# %%
a.find("a")
# Out:
# 1

# %%
a
# Out:
# 'lazar'

# %%
samp_list = ["lazar", "sarah", "kalpana", "thomas"];

# %%
for i in samp_list:
    print(i)
# Out:
# lazar
# sarah
# kalpana
# thomas

# %%
"".join(samp_list)
# Out:
# 'lazarsarahkalpanathomas'

# %%
" ~ ".join(samp_list)
# Out:
# 'lazar ~ sarah ~ kalpana ~ thomas'
