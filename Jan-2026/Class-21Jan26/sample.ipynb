# %%
a = "Hello"
print(a, "world", end="--")
# Out:
# Hello world--

# %%
print(a, "world", end="\n")
# Out:
# Hello world

# %%
print(a, "world", end="")
print("world")
# Out:
# Hello worldworld

# %%
print(a, "world", sep="*****")
print(a, "world", sep="_____")
# Out:
# Hello*****world
# Hello_____world
