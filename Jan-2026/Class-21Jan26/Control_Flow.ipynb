# %%
res = input("Enter a string: ")

family = ["lazar","sarah", "kalpana", "thomas", "elsamma", "mariya"]

for i in family:
    if res == i:
        print(i, "is my family member")
        break
else:
    print(res, "is not my family member")
# Out:
# sarah is my family member
